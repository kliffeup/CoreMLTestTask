# %%
import random

import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split

# !pip install surprise
# !pip install setuptools==58
# !pip install --user ml_metrics

from surprise import SVD, KNNWithMeans, Dataset, Reader, KNNBasic
from surprise.model_selection import GridSearchCV
from collections import defaultdict

# %% [markdown]
# ## Подготовка данных

# %%
data_path = "./data/"

# %%
rating = pd.read_csv(data_path + "rating.csv")
df = rating[rating["userId"] <= 1000]

# %%
df = df[["userId", "movieId", "rating"]]

# %%
from IPython.display import clear_output

train_data = []
selected_movies = set()

for user_id in tqdm(range(1, 1001)):
    ind = np.random.choice(df[df["userId"] == user_id].index)
    movie_id = int(df.loc[ind, :]["movieId"])
    rating = df.loc[ind, :]["rating"]
    
    selected_movies.add(movie_id)
    train_data.append([user_id, movie_id, rating])
    df.drop(ind)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
unique_movies = df["movieId"].unique()

for movie_id in tqdm(unique_movies):
    if movie_id not in selected_movies:
        ind = np.random.choice(df[df["movieId"] == movie_id].index)
        user_id = int(df.loc[ind, :]["userId"])
        rating = df.loc[ind, :]["rating"]

        train_data.append([user_id, movie_id, rating])
        df.drop(ind)
# Out:
#   0%|          | 0/9746 [00:00<?, ?it/s]

# %%
train_size = int(0.8 * (len(df) + len(train_data)) - len(train_data))

# %%
train, test = train_test_split(df, train_size=train_size, shuffle=True, random_state=42)

# %%
train = pd.concat((train, pd.DataFrame(train_data, columns=train.columns)))

# %%
reader = Reader(rating_scale=(0, 5))
# data = Dataset.load_from_df(df[['userId', 'movieId', 'rating']], reader)

# raw_ratings = data.raw_ratings                                             
# random.shuffle(raw_ratings)                                                

# threshold = int(.7 * len(raw_ratings))                                     
# trainset_raw_ratings = raw_ratings[:threshold]                             
# test_raw_ratings = raw_ratings[threshold:]                                 

# data.raw_ratings = trainset_raw_ratings
# trainset = data.build_full_trainset()
# testset = data.construct_testset(test_raw_ratings)
trainset = Dataset.load_from_df(train[['userId', 'movieId', 'rating']], reader)
# testset = Dataset.load_from_df(test[['userId', 'movieId', 'rating']], reader)

# %%
testset = []
for user_id in tqdm(test['userId'].unique()):
    rated_movies = set(train[train['userId'] == user_id]['movieId'])
    for movie_id in set(train['movieId']) - rated_movies:
        testset.append((user_id, movie_id, 0.))
# Out:
#   0%|          | 0/999 [00:00<?, ?it/s]

# %% [markdown]
# ## Получение топа рекомендаций (для моделей модуля `surpise`)

# %%
# функция взята из официального FAQ'a пакета `surprise`

def get_top_k(predictions, n=10):
    """Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    """

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = [movie_id for movie_id, _ in user_ratings[:n]]

    return top_n

# %% [markdown]
# ## Метрика: MAP@K

# %%
def apk(actual, predicted, k=10):
    """
    Computes the average precision at k.
    This function computes the average prescision at k between two lists of
    items.
    Parameters
    ----------
    actual : list
             A list of elements that are to be predicted (order doesn't matter)
    predicted : list
                A list of predicted elements (order does matter)
    k : int, optional
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The average precision at k over the input lists
    """
    if len(predicted) > k:
        predicted = predicted[:k]

    score = 0.0
    num_hits = 0.0

    for i, p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i + 1.0)

    if not actual:
        return 0.0

    return score / min(len(actual), k)

def mapk(predictions, test, threshold=4., k=10):
    recommendations = get_top_k(predictions, k)
    
    apks = []
    for user_id in tqdm(test['userId'].unique()):
        actual = list(test[(test['userId'] == user_id) & (test['rating'] >= threshold)]['movieId'])
        apks.append(apk(actual, recommendations[user_id], k))

    return np.mean(apks)

# %% [markdown]
# ## SVD

# %%
params_svd = {
    'n_factors': [i for i in range(50, 251, 50)],
#     'lr_all': [10**i for i in range(-3, 1)],
#     'reg_all': [10**i for i in range(-3, 1)],
}

grid_search_svd = GridSearchCV(
    algo_class=SVD,
    param_grid=params_svd,
    measures=['rmse'],
    joblib_verbose=1000,
    refit=True,
)

# %%
grid_search_svd.fit(trainset)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    6.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   10.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   13.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   17.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   22.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   27.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   32.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   37.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   42.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   49.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   55.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:  1.0min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:  1.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  1.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:  1.4min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:  1.6min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:  1.7min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:  1.8min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  2.0min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:  2.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:  2.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:  2.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:  2.7min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:  2.9min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:  2.9min finished

# %%
best_svd = grid_search_svd.best_estimator['rmse']

# %%
predictions = best_svd.test(testset)

# %%
mapk(predictions, test, threshold=4., k=10)
# Out:
#   0%|          | 0/999 [00:00<?, ?it/s]
# 0.02570686048860652

# %% [markdown]
# ## User-based approach

# %%
params_uknn = {
    'k': [i for i in range(10, 51, 10)],
    'sim_options': 
        {
            'name': ['msd', 'cosine', 'pearson', ],
            'user_based': [True, ],
            'min_support': [1, ],
        },
}

grid_search_uknn = GridSearchCV(
    algo_class=KNNWithMeans,
    param_grid=params_uknn,
    measures=['rmse'],
    joblib_verbose=1000,
    refit=True,
)

# %%
grid_search_uknn.fit(trainset)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.4s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.2s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    6.9s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    8.7s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   11.0s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   13.3s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   15.6s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   17.9s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   20.3s remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   22.9s remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   25.6s remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   59.9s remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:  1.0min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  1.1min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:  1.1min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:  1.2min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:  1.2min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:  1.2min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  1.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:  1.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:  1.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:  1.4min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:  1.4min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:  1.5min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:  1.5min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  1.6min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:  1.6min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:  1.7min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  1.7min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:  1.8min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:  1.8min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:  1.8min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:  1.9min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:  1.9min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:  1.9min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:  2.0min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:  2.0min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:  2.1min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:  2.1min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:  2.2min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:  2.2min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:  2.3min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:  2.3min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  2.4min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed:  2.4min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:  2.5min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:  2.5min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:  2.5min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  2.6min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed:  2.6min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:  2.7min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed:  2.7min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:  2.8min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:  2.8min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed:  2.9min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed:  2.9min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed:  3.0min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:  3.0min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  3.1min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed:  3.1min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:  3.2min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:  3.2min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:  3.2min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed:  3.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed:  3.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed:  3.4min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed:  3.4min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed:  3.5min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:  3.5min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed:  3.6min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed:  3.6min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  73 out of  73 | elapsed:  3.7min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  74 out of  74 | elapsed:  3.7min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  3.8min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  3.8min finished
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
best_uknn = grid_search_uknn.best_estimator['rmse']

# %%
predictions_uknn = best_uknn.test(testset)

# %%
mapk(predictions_uknn, test, threshold=4., k=10)
# Out:
#   0%|          | 0/999 [00:00<?, ?it/s]
# 0.00047110602666158223

# %% [markdown]
# ## Item-based approach

# %%
params_iknn = {
    'k': [i for i in range(10, 51, 10)],
    'sim_options': 
        {
            'name': ['msd', 'cosine', 'pearson', ],
            'user_based': [False, ],
            'min_support': [1, ],
        },
}

grid_search_iknn = GridSearchCV(
    algo_class=KNNWithMeans,
    param_grid=params_iknn,
    measures=['rmse'],
    joblib_verbose=1000,
    refit=True,
)

# %%
grid_search_iknn.fit(trainset)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   11.8s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   23.1s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   34.3s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   45.5s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   56.7s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  1.7min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  2.1min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  2.4min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  2.8min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:  3.3min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  3.8min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:  4.3min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:  4.8min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  5.3min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:  5.5min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:  5.7min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:  5.9min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:  6.1min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  6.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:  6.7min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:  7.1min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:  7.5min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:  7.8min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:  8.2min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:  8.7min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  9.2min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:  9.7min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 10.1min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 10.6min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed: 10.8min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 11.0min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed: 11.3min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed: 11.5min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed: 11.7min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed: 12.0min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed: 12.4min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed: 12.8min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed: 13.2min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 13.6min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed: 14.1min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed: 14.6min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed: 15.1min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed: 15.6min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 16.1min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed: 16.3min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed: 16.5min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed: 16.8min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed: 17.0min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed: 17.2min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed: 17.6min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed: 17.9min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed: 18.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 18.7min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed: 19.1min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed: 19.6min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed: 20.9min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed: 21.4min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed: 21.9min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed: 22.4min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed: 22.7min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed: 22.9min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed: 23.1min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed: 23.3min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed: 23.6min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed: 24.0min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed: 24.4min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed: 24.8min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed: 25.2min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed: 25.7min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed: 26.2min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed: 26.7min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  73 out of  73 | elapsed: 27.2min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  74 out of  74 | elapsed: 27.7min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed: 28.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed: 28.2min finished
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
best_iknn = grid_search_iknn.best_estimator['rmse']

# %%
predictions_iknn = best_iknn.test(testset)

# %%
mapk(predictions_iknn, test, threshold=4., k=10)
# Out:
#   0%|          | 0/999 [00:00<?, ?it/s]
# 0.0004858032635810414

# %% [markdown]
# ## user

# %%
params_ubknn = {
    'k': [i for i in range(10, 61, 10)],
    'sim_options': 
        {
            'name': ['msd', 'cosine', 'pearson', ],
            'user_based': [True, ],
            'min_support': [1, ],
        },
}

grid_search_ubknn = GridSearchCV(
    algo_class=KNNBasic,
    param_grid=params_ubknn,
    measures=['rmse'],
    joblib_verbose=1000,
    refit=True,
)

# %%
grid_search_ubknn.fit(trainset)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.3s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.1s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    6.8s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    8.5s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   10.9s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   13.2s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   15.5s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   17.8s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   20.1s remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   22.6s remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   25.3s remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   27.9s remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:   30.4s remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   33.0s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:   34.8s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:   36.6s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   38.4s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:   40.1s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   41.9s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:   44.3s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:   46.9s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:   49.5s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:   52.0s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:   54.5s remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:   57.2s remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:   60.0s remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:  1.0min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:  1.1min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  1.1min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:  1.2min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:  1.2min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:  1.2min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:  1.3min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:  1.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:  1.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:  1.4min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:  1.4min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:  1.5min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:  1.5min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:  1.6min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:  3.3min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:  3.3min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:  3.4min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  3.4min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed:  3.4min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:  3.5min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:  3.5min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:  3.5min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  3.6min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed:  3.6min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:  3.7min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed:  3.7min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:  3.7min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:  3.8min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed:  3.8min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed:  3.9min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed:  3.9min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:  4.0min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  4.0min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed:  4.1min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:  4.1min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:  4.1min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:  4.2min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed:  4.2min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed:  4.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed:  4.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed:  4.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed:  4.4min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:  4.4min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed:  4.5min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed:  4.5min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  73 out of  73 | elapsed:  4.6min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  74 out of  74 | elapsed:  4.6min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  4.7min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  76 out of  76 | elapsed:  4.7min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  77 out of  77 | elapsed:  4.8min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  78 out of  78 | elapsed:  4.8min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  79 out of  79 | elapsed:  4.8min remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  4.9min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  81 out of  81 | elapsed:  4.9min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  82 out of  82 | elapsed:  5.0min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  83 out of  83 | elapsed:  5.0min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  84 out of  84 | elapsed:  5.0min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  85 out of  85 | elapsed:  5.1min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  86 out of  86 | elapsed:  5.1min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:  5.2min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  88 out of  88 | elapsed:  5.3min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  89 out of  89 | elapsed:  5.3min remaining:    0.0s
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:  5.4min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:  5.4min finished
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
best_ubknn = grid_search_ubknn.best_estimator['rmse']

# %%
predictions_ubknn = best_ubknn.test(testset)

# %%
mapk(predictions_ubknn, test, threshold=4., k=10)
# Out:
#   0%|          | 0/999 [00:00<?, ?it/s]
# 0.0

# %% [markdown]
# ## item

# %%
params_ibknn = {
    'k': [i for i in range(10, 51, 10)],
    'sim_options': 
        {
            'name': ['msd', 'cosine', 'pearson', ],
            'user_based': [False, ],
            'min_support': [1, ],
        },
}

grid_search_ibknn = GridSearchCV(
    algo_class=KNNWithMeans,
    param_grid=params_ibknn,
    measures=['rmse'],
    joblib_verbose=1000,
    refit=True,
)

# %%
grid_search_ibknn.fit(trainset)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   11.6s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   22.4s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   33.3s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   44.1s remaining:    0.0s
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   54.8s remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  1.6min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  2.0min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  2.3min remaining:    0.0s
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  2.7min remaining:    0.0s
# Computing the pearson similarity matrix...
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-117-b7241418c988> in <module>
# ----> 1 grid_search_ibknn.fit(trainset)
#
# ~\anaconda3\lib\site-packages\surprise\model_selection\search.py in fit(self, data)
#      86                                                        cv.split(data))
#      87         )
# ---> 88         out = Parallel(n_jobs=self.n_jobs,
#      89                        pre_dispatch=self.pre_dispatch,
#      90                        verbose=self.joblib_verbose)(delayed_list)
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\surprise\model_selection\validation.py in fit_and_score(algo, trainset, testset, measures, return_train_measures)
#     164
#     165     start_fit = time.time()
# --> 166     algo.fit(trainset)
#     167     fit_time = time.time() - start_fit
#     168     start_test = time.time()
#
# ~\anaconda3\lib\site-packages\surprise\prediction_algorithms\knns.py in fit(self, trainset)
#     176
#     177         SymmetricAlgo.fit(self, trainset)
# --> 178         self.sim = self.compute_similarities()
#     179
#     180         self.means = np.zeros(self.n_x)
#
# ~\anaconda3\lib\site-packages\surprise\prediction_algorithms\algo_base.py in compute_similarities(self)
#     247             if getattr(self, 'verbose', False):
#     248                 print('Computing the {0} similarity matrix...'.format(name))
# --> 249             sim = construction_func[name](*args)
#     250             if getattr(self, 'verbose', False):
#     251                 print('Done computing similarity matrix.')
#
# ~\anaconda3\lib\site-packages\surprise\similarities.pyx in surprise.similarities.pearson()
#
# MemoryError: Unable to allocate 694. MiB for an array with shape (9536, 9536) and data type float64

# %%
best_ibknn = grid_search_ibknn.best_estimator['rmse']

# %%
predictions_ibknn = best_ibknn.test(testset)

# %%
mapk(predictions_ibknn, test, threshold=4., k=10)
